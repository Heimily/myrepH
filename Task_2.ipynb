# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
credit = pd.read_csv('default of credit card clients.csv', header=1)
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           AGE      BILL_AMT1  \
# count  30000.000000    30000.000000  30000.000000   30000.000000
# mean   15000.500000   167484.322667     35.485500   51223.330900
# std     8660.398374   129747.661567      9.217904   73635.860576
# min        1.000000    10000.000000     21.000000 -165580.000000
# 25%     7500.750000    50000.000000     28.000000    3558.750000
# 50%    15000.500000   140000.000000     34.000000   22381.500000
# 75%    22500.250000   240000.000000     41.000000   67091.000000
# max    30000.000000  1000000.000000     79.000000  964511.000000
#
#            BILL_AMT2     BILL_AMT3      BILL_AMT4      BILL_AMT5  \
# count   30000.000000  3.000000e+04   30000.000000   30000.000000
# mean    49179.075167  4.701315e+04   43262.948967   40311.400967
# std     71173.768783  6.934939e+04   64332.856134   60797.155770
# min    -69777.000000 -1.572640e+05 -170000.000000  -81334.000000
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID           30000 non-null int64
# LIMIT_BAL    30000 non-null int64
# SEX          30000 non-null category
# EDUCATION    30000 non-null category
# MARRIAGE     30000 non-null category
# AGE          30000 non-null int64
# PAY_0        30000 non-null category
# PAY_2        30000 non-null category
# PAY_3        30000 non-null category
# PAY_4        30000 non-null category
# PAY_5        30000 non-null object
# PAY_6        30000 non-null object
# BILL_AMT1    30000 non-null int64
# BILL_AMT2    30000 non-null int64
# BILL_AMT3    30000 non-null int64
# BILL_AMT4    30000 non-null int64
# BILL_AMT5    30000 non-null int64
# BILL_AMT6    30000 non-null int64
# PAY_AMT1     30000 non-null int64
# PAY_AMT2     30000 non-null int64
# PAY_AMT3     30000 non-null int64
# PAY_AMT4     30000 non-null int64
# PAY_AMT5     30000 non-null int64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'Default'],
#       dtype='object')

# %%
credit.drop("ID", axis=1)
# Out:
#        LIMIT_BAL     SEX    EDUCATION MARRIAGE  AGE                 PAY_0  \
# 0          20000  Female   University  Married   24  2 to 3 months delays
# 1         120000  Female   University   Single   26          Paid in full
# 2          90000  Female   University   Single   34      Revolving credit
# 3          50000  Female   University  Married   37      Revolving credit
# 4          50000    Male   University  Married   57          Paid in full
# ...          ...     ...          ...      ...  ...                   ...
# 29995     220000    Male  High School  Married   39      Revolving credit
# 29996     150000    Male  High School   Single   43          Paid in full
# 29997      30000    Male   University   Single   37  4 to 5 months delays
# 29998      80000    Male  High School  Married   41        1 months delay
# 29999      50000    Male   University  Married   46      Revolving credit
#
#                       PAY_2                 PAY_3             PAY_4 PAY_5  \
# ...

# %%
credit.rename(columns={'default payment next month': 'Default'}, inplace = True)

# %%
credit ['SEX']= credit ['SEX'] .astype ('str')
credit ['EDUCATION']= credit ['EDUCATION'] .astype ('str')
credit ['MARRIAGE']= credit ['MARRIAGE'] .astype ('str')
credit ['PAY_0']= credit ['PAY_0'] .astype ('str')
credit ['PAY_2']= credit ['PAY_2'] .astype ('str')
credit ['PAY_3']= credit ['PAY_3'] .astype ('str')
credit ['PAY_4']= credit ['PAY_4'] .astype ('str')
credit ['PAY_5']= credit ['PAY_5'] .astype ('str')
credit ['PAY_6']= credit ['PAY_6'] .astype ('str')
credit ['Default']= credit ['Default'] .astype ('str')

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID           30000 non-null int64
# LIMIT_BAL    30000 non-null int64
# SEX          30000 non-null object
# EDUCATION    30000 non-null object
# MARRIAGE     30000 non-null object
# AGE          30000 non-null int64
# PAY_0        30000 non-null object
# PAY_2        30000 non-null object
# PAY_3        30000 non-null object
# PAY_4        30000 non-null object
# PAY_5        30000 non-null object
# PAY_6        30000 non-null object
# BILL_AMT1    30000 non-null int64
# BILL_AMT2    30000 non-null int64
# BILL_AMT3    30000 non-null int64
# BILL_AMT4    30000 non-null int64
# BILL_AMT5    30000 non-null int64
# BILL_AMT6    30000 non-null int64
# PAY_AMT1     30000 non-null int64
# PAY_AMT2     30000 non-null int64
# PAY_AMT3     30000 non-null int64
# PAY_AMT4     30000 non-null int64
# PAY_AMT5     30000 non-null int64
# PAY_AMT6     30000 non-null int64
# ...

# %%
credit.loc[credit['SEX'].str.contains('1'),'SEX']='Male'
credit.loc[credit['SEX'].str.contains('2'),'SEX']='Female'
credit.loc[credit['EDUCATION'].str.contains('0'),'EDUCATION']='Others'
credit.loc[credit['EDUCATION'].str.contains('1'),'EDUCATION']='Graduate School'
credit.loc[credit['EDUCATION'].str.contains('2'),'EDUCATION']='University'
credit.loc[credit['EDUCATION'].str.contains('3'),'EDUCATION']='High School'
credit.loc[credit['EDUCATION'].str.contains('4'),'EDUCATION']='Others'
credit.loc[credit['EDUCATION'].str.contains('5'),'EDUCATION']='Others'
credit.loc[credit['EDUCATION'].str.contains('6'),'EDUCATION']='Others'
credit.loc[credit['Default'].str.contains('0'),'Default']='Pay'
credit.loc[credit['Default'].str.contains('1'),'Default']='Delay'
credit.loc[credit['MARRIAGE'].str.contains('1'),'MARRIAGE']='Married'
credit.loc[credit['MARRIAGE'].str.contains('2'),'MARRIAGE']='Single'
credit.loc[credit['MARRIAGE'].str.contains('3'),'MARRIAGE']='Divorced'
credit.loc[credit['MARRIAGE'].str.contains('4'),'MARRIAGE']='Others'
credit.loc[credit['PAY_0'].str.contains('-2'),'PAY_0']='No consumption'
credit.loc[credit['PAY_0'].str.contains('-1'),'PAY_0']='Paid in full'
credit.loc[credit['PAY_0'].str.contains('0'),'PAY_0']='Revolving credit'
credit.loc[credit['PAY_0'].str.contains('1'),'PAY_0']='1 months delay'
credit.loc[credit['PAY_0'].str.contains('2'),'PAY_0']='2 to 3 months delays'
credit.loc[credit['PAY_0'].str.contains('3'),'PAY_0']='2 to 3 months delays'
credit.loc[credit['PAY_0'].str.contains('4'),'PAY_0']='4 to 5 months delays'
credit.loc[credit['PAY_0'].str.contains('5'),'PAY_0']='4 to 5 months delays'
credit.loc[credit['PAY_0'].str.contains('6'),'PAY_0']='6 to 7 months delays'
credit.loc[credit['PAY_0'].str.contains('7'),'PAY_0']='6 to 7 months delays'
credit.loc[credit['PAY_0'].str.contains('8'),'PAY_0']='8+ months delays'
credit.loc[credit['PAY_0'].str.contains('9'),'PAY_0']='8+ months delays'
credit.loc[credit['PAY_2'].str.contains('-2'),'PAY_2']='No consumption'
credit.loc[credit['PAY_2'].str.contains('-1'),'PAY_2']='Paid in full'
credit.loc[credit['PAY_2'].str.contains('0'),'PAY_2']='Revolving credit'
credit.loc[credit['PAY_2'].str.contains('1'),'PAY_2']='1 months delay'
credit.loc[credit['PAY_2'].str.contains('2'),'PAY_2']='2 to 3 months delays'
credit.loc[credit['PAY_2'].str.contains('3'),'PAY_2']='2 to 3 months delays'
credit.loc[credit['PAY_2'].str.contains('4'),'PAY_2']='4 to 5 months delays'
credit.loc[credit['PAY_2'].str.contains('5'),'PAY_2']='4 to 5 months delays'
credit.loc[credit['PAY_2'].str.contains('6'),'PAY_2']='6 to 7 months delays'
credit.loc[credit['PAY_2'].str.contains('7'),'PAY_2']='6 to 7 months delays'
credit.loc[credit['PAY_2'].str.contains('8'),'PAY_2']='8+ months delays'
credit.loc[credit['PAY_2'].str.contains('9'),'PAY_2']='8+ months delays'
credit.loc[credit['PAY_3'].str.contains('-2'),'PAY_3']='No consumption'
credit.loc[credit['PAY_3'].str.contains('-1'),'PAY_3']='Paid in full'
credit.loc[credit['PAY_3'].str.contains('0'),'PAY_3']='Revolving credit'
credit.loc[credit['PAY_3'].str.contains('1'),'PAY_3']='1 months delay'
credit.loc[credit['PAY_3'].str.contains('2'),'PAY_3']='2 to 3 months delays'
credit.loc[credit['PAY_3'].str.contains('3'),'PAY_3']='2 to 3 months delays'
credit.loc[credit['PAY_3'].str.contains('4'),'PAY_3']='4 to 5 months delays'
credit.loc[credit['PAY_3'].str.contains('5'),'PAY_3']='4 to 5 months delays'
credit.loc[credit['PAY_3'].str.contains('6'),'PAY_3']='6 to 7 months delays'
credit.loc[credit['PAY_3'].str.contains('7'),'PAY_3']='6 to 7 months delays'
credit.loc[credit['PAY_3'].str.contains('8'),'PAY_3']='8+ months delays'
credit.loc[credit['PAY_3'].str.contains('9'),'PAY_3']='8+ months delays'
credit.loc[credit['PAY_4'].str.contains('-2'),'PAY_4']='No consumption'
credit.loc[credit['PAY_4'].str.contains('-1'),'PAY_4']='Paid in full'
credit.loc[credit['PAY_4'].str.contains('0'),'PAY_4']='Revolving credit'
credit.loc[credit['PAY_4'].str.contains('1'),'PAY_4']='1 months delay'
credit.loc[credit['PAY_4'].str.contains('2'),'PAY_4']='2 to 3 months delays'
credit.loc[credit['PAY_4'].str.contains('3'),'PAY_4']='2 to 3 months delays'
credit.loc[credit['PAY_4'].str.contains('4'),'PAY_4']='4 to 5 months delays'
credit.loc[credit['PAY_4'].str.contains('5'),'PAY_4']='4 to 5 months delays'
credit.loc[credit['PAY_4'].str.contains('6'),'PAY_4']='6 to 7 months delays'
credit.loc[credit['PAY_4'].str.contains('7'),'PAY_4']='6 to 7 months delays'
credit.loc[credit['PAY_4'].str.contains('8'),'PAY_4']='8+ months delays'
credit.loc[credit['PAY_4'].str.contains('9'),'PAY_4']='8+ months delays'
credit
# Out:
#           ID  LIMIT_BAL     SEX    EDUCATION MARRIAGE  AGE  \
# 0          1      20000  Female   University  Married   24
# 1          2     120000  Female   University   Single   26
# 2          3      90000  Female   University   Single   34
# 3          4      50000  Female   University  Married   37
# 4          5      50000    Male   University  Married   57
# ...      ...        ...     ...          ...      ...  ...
# 29995  29996     220000    Male  High School  Married   39
# 29996  29997     150000    Male  High School   Single   43
# 29997  29998      30000    Male   University   Single   37
# 29998  29999      80000    Male  High School  Married   41
# 29999  30000      50000    Male   University  Married   46
#
#                       PAY_0                 PAY_2                 PAY_3  \
# 0      2 to 3 months delays  2 to 3 months delays          Paid in full
# 1              Paid in full  2 to 3 months delays      Revolving credit
# ...

# %%
credit ['SEX']= credit ['SEX'].astype('category')
credit ['EDUCATION']= credit ['EDUCATION'].astype('category')
credit ['MARRIAGE']= credit ['MARRIAGE'].astype('category')
credit ['PAY_0']= credit ['PAY_0'].astype('category')
credit ['PAY_2']= credit ['PAY_2'].astype('category')
credit ['PAY_3']= credit ['PAY_3'].astype('category')
credit ['PAY_4']= credit ['PAY_4'].astype('category')

# %%
plt.hist(credit['LIMIT_BAL'])
plt.title ('Given Credit')
plt.xlabel('Dollar')
plt.ylabel("Frequency")
plt.show()

# %%
plt.plot(credit['LIMIT_BAL'])
plt.show()

# %%
x = credit['Default']
y = credit['LIMIT_BAL']

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'Default'],
#       dtype='object')

# %%
plt.scatter(x,y)
plt.show()

# %%
A = credit['LIMIT_BAL']
plt.boxplot(A,0,'gD')
plt.title ('Given Credit Amount')
plt.ylabel("Distribution")
plt.show()

# %%
pd.crosstab(credit['Default'], credit['EDUCATION']).plot(kind= 'bar')
plt.title ('Default payment next month by Education')
plt.xlabel('Default payment')
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
pd.crosstab(credit['Default'], credit['SEX']).plot(kind= 'bar')
plt.title ('Default payment next month')
plt.xlabel('Default payment')
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
credit.groupby('SEX')['SEX'].count ()
# Out:
# LIMIT_BAL  10000    16000    20000    30000    40000    50000    60000    \
# Default
# Delay          197        0      698      568       92      885      233
# Pay            296        2     1278     1042      138     2480      592
#
# LIMIT_BAL  70000    80000    90000    ...  700000   710000   720000   730000   \
# Default                               ...
# Delay          210      363      166  ...        0        1        1        0
# Pay            521     1204      485  ...        8        5        2        2
#
# LIMIT_BAL  740000   750000   760000   780000   800000   1000000
# Default
# Delay            1        0        0        0        0        0
# Pay              1        4        1        2        2        1
#
# [2 rows x 81 columns]

# %%
pd.crosstab(credit['Default'], credit['Default'])
# Out:
# Default  Delay    Pay
# Default
# Delay     6636      0
# Pay          0  23364

# %%
pd.crosstab(credit['SEX'], credit['Default'])
# Out:
# Default  Delay    Pay
# SEX
# Female    3763  14349
# Male      2873   9015

# %%
credit.groupby('SEX')['SEX'].count ()
# Out:
# SEX
# Female    18112
# Male      11888
# Name: SEX, dtype: int64

# %%
pd.crosstab(credit['EDUCATION'], credit['Default'])
# Out:
# Default          Delay    Pay
# EDUCATION
# Graduate School   2036   8549
# High School       1237   3680
# Others              33    435
# University        3330  10700

# %%
pd.crosstab(credit['LIMIT_BAL'], credit['SEX'])
# Out:
# SEX        Female  Male
# LIMIT_BAL
# 10000         187   306
# 16000           1     1
# 20000         866  1110
# 30000        1017   593
# 40000         143    87
# ...           ...   ...
# 750000          4     0
# 760000          0     1
# 780000          1     1
# 800000          0     2
# 1000000         1     0
#
# [81 rows x 2 columns]

# %%
bins =[18, 30, 40, 50, 90]
labels= ['18-29','30-39','40-49', '50+']
credit ['AGE2'] = pd.cut(credit['AGE'],bins, labels=labels)
credit ['AGE2']
# Out:
# 0        18-29
# 1        18-29
# 2        30-39
# 3        30-39
# 4          50+
#          ...
# 29995    30-39
# 29996    40-49
# 29997    30-39
# 29998    40-49
# 29999    40-49
# Name: AGE2, Length: 30000, dtype: category
# Categories (4, object): [18-29 < 30-39 < 40-49 < 50+]

# %%
graph=sns.catplot('AGE2', data=credit, hue='Default', kind='count',aspect=1)
graph.set_xlabels('AGE')

# %%
corrMat = credit.corr()
print(corrMat)
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %%
covMat = credit.cov()
print(covMat)
# Out:
#                                       ID     LIMIT_BAL          SEX  \
# ID                          7.500250e+07  2.941664e+07    78.356379
# LIMIT_BAL                   2.941664e+07  1.683446e+10  1571.050630
# SEX                         7.835638e+01  1.571051e+03     0.239247
# EDUCATION                   2.681543e+02 -2.247403e+04     0.005502
# MARRIAGE                   -1.314525e+02 -7.323670e+03    -0.008014
# AGE                         1.491057e+03  1.730767e+05    -0.409726
# PAY_0                      -2.975726e+02 -3.954593e+04    -0.031685
# PAY_2                      -1.162770e+02 -4.603765e+04    -0.041442
# PAY_3                      -1.916922e+02 -4.443225e+04    -0.038694
# PAY_4                      -2.769132e+01 -4.057181e+04    -0.034411
# PAY_5                      -2.178600e+02 -3.667056e+04    -0.030521
# PAY_6                      -2.018774e+02 -3.509308e+04    -0.024754
# BILL_AMT1                   1.236447e+07  2.727020e+09 -1211.694332
# ...
